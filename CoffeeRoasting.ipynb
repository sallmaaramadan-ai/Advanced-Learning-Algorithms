# %% [markdown]
# ## Coffee Roasting Neural Network (TensorFlow)
#
# This notebook implements a simple neural network using TensorFlow to classify coffee roasting quality based on temperature and duration.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('./deeplearning.mplstyle')
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from lab_utils_common import dlc
from lab_coffee_utils import load_coffee_data, plt_roast, plt_prob, plt_layer, plt_network, plt_output_unit
import logging
logging.getLogger("tensorflow").setLevel(logging.ERROR)
tf.autograph.set_verbosity(0)

# %% [markdown]
# dataset

# %%
X,Y = load_coffee_data();
print(X.shape, Y.shape)
# Out:
# (200, 2) (200, 1)

# %% [markdown]
# normalize data

# %%
norm_l = tf.keras.layers.Normalization(axis=-1)
norm_l.adapt(X)  # learns mean, variance
Xn = norm_l(X)

# %%
Xt = np.tile(Xn,(1000,1))
Yt= np.tile(Y,(1000,1))
print(Xt.shape, Yt.shape)
# Out:
# (200000, 2) (200000, 1)

# %% [markdown]
# build model

# %%
model= Sequential([
    tf.keras.Input(shape=(2,)),
    Dense(3,activation='sigmoid'),
    Dense(1,activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 3)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13 (52.00 B)
#  Trainable params: 13 (52.00 B)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# model training

# %%
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.01),
)
model.fit(
    Xt,Yt,
    epochs=10,
)
# Out:
# Epoch 1/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - loss: 0.2902
# Epoch 2/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.1323
# Epoch 3/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.1210
# Epoch 4/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.1010
# Epoch 5/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.0242
# Epoch 6/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 10s 2ms/step - loss: 0.0138
# Epoch 7/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 11s 2ms/step - loss: 0.0092
# Epoch 8/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.0068
# Epoch 9/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.0048
# Epoch 10/10
# 6250/6250 ━━━━━━━━━━━━━━━━━━━━ 12s 2ms/step - loss: 0.0034

# %% [markdown]
# prediction

# %%
X_test = np.array([
    [200,13.9],  # postive example
    [200,17]])   # negative example
X_testn = norm_l(X_test)
predictions = model.predict(X_testn)
print("predictions = \n", predictions)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# predictions =
#  [[9.7566873e-01]
#  [1.3764505e-04]]

# %%
yhat = (predictions >= 0.5).astype(int)
print(f"decisions = \n{yhat}")
# Out:
# decisions =
# [[1]
#  [0]]

# %% [markdown]
# **The model successfully learned to classify coffee roasting quality using only two input features**
